# %%
import pandas as pd

# %%
with open('titanic.csv', 'r') as f:
    df = pd.read_csv('titanic.csv')
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
df['sex'].value_counts()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
df.groupby('sex')['age'].idxmin()
# Out:
# sex
# female    763
# male      747
# Name: age, dtype: int64

# %%
df.iloc[747]
# Out:
# pclass                                             3
# survived                                           0
# name         Danbom, Master. Gilbert Sigvard Emanuel
# sex                                             male
# age                                             0.33
# sibsp                                              0
# parch                                              2
# ticket                                        347080
# fare                                            14.4
# cabin                                            NaN
# embarked                                           S
# boat                                             NaN
# body                                             NaN
# home.dest                                Stanton, IA
# Name: 747, dtype: object

# %%
df['survived'].sum()
# Out:
# 500

# %%
df[(df['sex'] == 'female') & (df['age'] < 25) & (df['sibsp'] ==0) & (df['parch'] == 0)]
# Out:
#       pclass  survived                                               name  \
# 12         1         1                      Aubart, Mme. Leontine Pauline
# 73         1         1                               Cleaver, Miss. Alice
# 137        1         1                       Graham, Miss. Margaret Edith
# 153        1         1                     Hays, Miss. Margaret Bechstein
# 190        1         1                      Longley, Miss. Gretchen Fiske
# 195        1         1                              Maioni, Miss. Roberta
# 199        1         1   Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")
# 255        1         1                               Sagesser, Mlle. Emma
# 315        1         1                           Willard, Miss. Constance
# 344        2         1                            Bentham, Miss. Lilian W
# 349        2         1                      Brown, Miss. Amelia "Mildred"
# 380        2         1                         Cook, Mrs. (Selena Rogers)
# ...

# %%
df[(df['boat'] == '11') & (df['survived'] != 0)].shape
# Out:
# (25, 14)

# %%
data = pd.DataFrame()
data['male_age'] = df[(df['sex'] == 'male')].mean()
data['female_age'] = df[(df['sex'] == 'female')].mean()
data
# Out:
#             male_age  female_age
# pclass      2.372479    2.154506
# survived    0.190985    0.727468
# age        30.585228   28.687088
# sibsp       0.413998    0.652361
# parch       0.247924    0.633047
# fare       26.154601   46.198097
# body      160.398230  166.625000

# %%
df['home.dest'].value_counts().sort_values()
# Out:
# Myren, Sweden New York, NY                             1
# Syria Youngstown, OH                                   1
# Oslo, Norway Bayonne, NJ                               1
# East Bridgewater, MA                                   1
# Omaha, NE                                              1
# Tranvik, Finland New York                              1
# Kingwilliamstown, Co Cork, Ireland Glens Falls, NY     1
# Bryn Mawr, PA, USA                                     1
# Provo, UT                                              1
# Weston-Super-Mare / Moose Jaw, SK                      1
# Bournemouth, England                                   1
# Folkstone, Kent / New York, NY                         1
# Oskarshamn, Sweden Minneapolis, MN                     1
# Oslo, Norway Cameron, WI                               1
# Portugal / Sau Paulo, Brazil                           1
# India / Pittsburgh, PA                                 1
# ...
